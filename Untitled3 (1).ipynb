# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time):
  a=0.1
  b=-1
  c=30
  temprature = a*(time**2)+b*time+c
  return temprature

def main():
  time_values = np.arange(0,10,0.1)
  temprature_hardcoded = quadratic_model(time_values)
  # plot the results
  plt.plot(time_values,temprature_hardcoded,label = 'hard coded coefficents')
  plt.xlabel('time')
  plt.ylabel('temprature')
  plt.legend()
  plt.title('weather moddeling with quadratic equation')
  plt.show()

if __name__ == "__main__":
  main()

# %%
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time, a, b, c):
  temprature = a*(time**2)+b*time+c
  return temprature

def main():
  time = np.arange(0,10,0.1)
  # get user input and convert to integers
  a_input = int(input("Enter the value for a: "))
  b_input = int(input("Enter the value for b: "))
  c_input = int(input("Enter the value for c: "))
  temprature_keyboard = quadratic_model(time, a_input, b_input, c_input)
  # plot the results
  plt.plot(time,temprature_keyboard,label = 'user input coefficents')
  plt.xlabel('time')
  plt.ylabel('temprature')
  plt.legend()
  plt.title('weather moddeling with quadratic equation')
  plt.show()

if __name__ == "__main__":
  main()
# Out:
# Enter the value for a: 2
# Enter the value for b: 56
# Enter the value for c: 7654

# %%
import matplotlib.pyplot as plt
import numpy as np
def quadratic_model(time, a, b,c):

    temprature = a*(time**2)+b*time+c
    return temprature

def main():
   with open("sef.txt","r")as file:
      lines = file.readlines()
      a,b,c = map(float,lines)
      print(f"read values: a={a}, b={b}, c={c}")
      time = np.arange(0,10,0.1)

   temprature_keyboard = quadratic_model(time, a, b, c)
   plt.plot(time,temprature_keyboard,label = 'user input coefficents')
   plt.xlabel('time')
   plt.ylabel('temprature')
   plt.legend()
   plt.title('weather moddeling with quadratic equation with user input')
   plt.show()
if __name__ == "__main__":
     main()
# Out:
# read values: a=5.0, b=6.0, c=7.0

# %%
import matplotlib.pyplot as plt
import numpy as np
def quad_model(Time, coeffs):
    a, b, c = coeffs
    temp = a * (Time**2) + b * Time + c
    return temp
def main():
    num_sets = int(input("Enter the number of coefficient sets: "))
    all_sets = []
    for _ in range(num_sets):
        a = float(input("Enter the value of 'a': "))
        b = float(input("Enter the value of 'b': "))
        c = float(input("Enter the value of 'c': "))
        all_sets.append((a, b, c))
    print("Give a time range:")
    x = float(input("Enter the start range: "))
    y = float(input("Enter the final range: "))
    time_v = np.linspace(x, y, 50)
    plt.figure(figsize=(8, 6))
    for coeffs in all_sets:
        temp_user = quad_model(time_v, coeffs)
        plt.plot(time_v, temp_user, label=f"Set: {coeffs}")
    plt.xlabel("Time")
    plt.ylabel("Temperature")
    plt.legend()
    plt.title("Weather modeling with user given coefficient sets")
    plt.grid(True)
    plt.show()
if __name__ == "__main__":
    main()
# Out:
# Enter the number of coefficient sets: 3
# Enter the value of 'a': 34
# Enter the value of 'b': 35
# Enter the value of 'c': 36
# Enter the value of 'a': 45
# Enter the value of 'b': 34
# Enter the value of 'c': 29
# Enter the value of 'a': 23
# Enter the value of 'b': 24
# Enter the value of 'c': 25
# Give a time range:
# Enter the start range: 20
# Enter the final range: 50

# %%
import matplotlib.pyplot as plt
import numpy as np
def quad_model(Time, coeffs):
    a, b, c = coeffs
    temp = a * (Time**2) + b * Time + c
    return temp
def main():
    set1 = {float(input("Enter the value of 'a': ")), float(input("Enter the value of 'b': ")), float(input("Enter the value of 'c': "))}
    print(set1)
    print("Give a time range:")
    x = float(input("Enter the start range: "))
    y = float(input("Enter the final range: "))
    time_v = np.linspace(x, y, 50)
    temp_user = quad_model(time_v, set1)
    plt.plot(time_v, temp_user, label="user given values")
    plt.xlabel("time")
    plt.ylabel("temp")
    plt.legend()
    plt.title("Weather modeling with user given values and range in QE")
    plt.show()
if __name__ == "__main__":
    main()
# Out:
# Enter the value of 'a': 2
# Enter the value of 'b': 7
# Enter the value of 'c': 4
# {2.0, 4.0, 7.0}
# Give a time range:
# Enter the start range: 1
# Enter the final range: 10

# %%
import matplotlib.pyplot as plt
import numpy as np
def quad_model(time):
  a=0.1
  b=-1
  c=30
  temp = a * (time**2) + b * time + c
  return temp
def quad_model2(time):
  a=float(input('Enter a value:'))
  b=float(input('Enter b value:'))
  c=float(input('Enter c value:'))
  temp = a * (time**2) + b * time + c
  return temp
def main():
  time_value=np.linspace(0, 10, 50)
  temp1_user = quad_model(time_value)
  plt.plot(time_value, temp1_user,label='hard-coded')
  temp2_user = quad_model2(time_value)
  plt.plot(time_value, temp2_user,label='user given input')
  plt.xlabel('Time')
  plt.ylabel('Temperature')
  plt.legend()
  plt.title('Weather Modeling ')
  plt.grid(True)
  plt.show()
if __name__ == '__main__':
    main()
# Out:
# Enter a value:3
# Enter b value:4
# Enter c value:5
